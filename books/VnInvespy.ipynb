# %%
import pip


# %pip install investpy
# Out:
# Collecting investpy
#   Downloading investpy-1.0.8.tar.gz (4.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 2.0 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Collecting Unidecode>=1.1.1
#   Downloading Unidecode-1.3.4-py3-none-any.whl (235 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.9/235.9 kB 1.8 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: setuptools>=41.2.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from investpy) (58.1.0)
# Requirement already satisfied: numpy>=1.17.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from investpy) (1.22.4)
# Requirement already satisfied: pandas>=0.25.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from investpy) (1.1.5)
# Requirement already satisfied: lxml>=4.4.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from investpy) (4.6.3)
# Requirement already satisfied: requests>=2.22.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from investpy) (2.26.0)
# Requirement already satisfied: pytz>=2019.3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from investpy) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pandas>=0.25.1->investpy) (2.8.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests>=2.22.0->investpy) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests>=2.22.0->investpy) (2021.5.30)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests>=2.22.0->investpy) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests>=2.22.0->investpy) (1.26.7)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from python-dateutil>=2.7.3->pandas>=0.25.1->investpy) (1.16.0)
# Building wheels for collected packages: investpy
#   Building wheel for investpy (setup.py) ... done
#   Created wheel for investpy: filename=investpy-1.0.8-py3-none-any.whl size=4481592 sha256=4314f1b8abf5ba4b0203dff7bed1d7d999e03ffd62bb94233d595370fc200e26
#   Stored in directory: /Users/taipm/Library/Caches/pip/wheels/db/f4/ae/980b93b0257620bc8e4afc98a854a7a746a33eb8335fd07906
# Successfully built investpy
# Installing collected packages: Unidecode, investpy
# Successfully installed Unidecode-1.3.4 investpy-1.0.8
# Note: you may need to restart the kernel to use updated packages.

# %%
#VND

import pandas as pd
import numpy as np
import datetime as dt# Xử lý ngày tháng
import investpy

# %%
start = "01/01/2015"
end  = dt.datetime.now().strftime("%d/%m/%Y")
company = "CTG"
CTG = investpy.get_stock_historical_data(stock= company, country= 'vietnam', from_date = start, to_date = end)              
CTG.tail()
# Out:
#                Open     High      Low    Close   Volume Currency
# Date
# 2022-07-19  26700.0  28000.0  25050.0  26550.0  2702900      VND
# 2022-07-20  27000.0  27350.0  26600.0  27050.0  4316400      VND
# 2022-07-21  27200.0  27500.0  27050.0  27500.0  4824700      VND
# 2022-07-22  27500.0  28000.0  25600.0  26900.0  3253000      VND
# 2022-07-25  26850.0  27100.0  26600.0  26700.0  1625800      VND

# %%
start = "01/01/2015"
end  = dt.datetime.now().strftime("%d/%m/%Y")
company = "VND"
VND = investpy.get_stock_historical_data(stock= company, country= 'vietnam', from_date = start, to_date = end)              
VND.tail()
# Out:
#                Open     High      Low    Close    Volume Currency
# Date
# 2022-07-19  19000.0  19100.0  18400.0  18750.0  22450900      VND
# 2022-07-20  19100.0  19650.0  19000.0  19200.0  23701000      VND
# 2022-07-21  19450.0  19550.0  19050.0  19150.0  16010200      VND
# 2022-07-22  19150.0  19400.0  18900.0  18950.0  15427200      VND
# 2022-07-25  18650.0  18850.0  18400.0  18700.0  10416500      VND

# %%
def GetProfit(symbol,start,end):
    #start = "01/01/2015"
    #end  = dt.datetime.now().strftime("%d/%m/%Y")
    company = symbol
    df_stock = investpy.get_stock_historical_data(stock= company, country= 'vietnam', from_date = start, to_date = end)
    p_start = df_stock['Close'][0]
    p_end = df_stock[-1]
    profit = ((p_end-p_start)/p_start)*100
    print(f'{p_start} -> {p_end}')
    return profit

x = GetProfit('VND',"01/08/2022","04/08/2022")
print(x)
